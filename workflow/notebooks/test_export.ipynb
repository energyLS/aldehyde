# %% [markdown]
# ## Note: this was designed to be used in PyPSA-Earth-Sec

# %%
import pypsa

# %%
#n = pypsa.Network("results/fix_demand/prenetworks/elec_s_4_ec_lc1.0__Co2L0.90-144H_2030_0.071_DF_presec.nc")
#n = pypsa.Network("results/fix_demand/prenetworks/elec_s_4_ec_lc1.0_Co2L_144H_2030_0.071_DF_presec.nc")
prefix = "/mnt/c/Users/scl38887/Documents/git/"
ald = "aldehyde/resources/pypsaearthsec/with_h2_network_6h/postnetworks/elec_s_4_ec_lc1.0_Co2L.50_6H_2030_0.071_DF_20export.nc"
earthsec = "pypsa-earth-sec/results/with_h2_network_2000h/postnetworks/elec_s_4_ec_lc1.0_Co2L0.10_6H_2030_0.071_DF_40export.nc"

#/mnt/c/Users/scl38887/Documents/git/aldehyde/resources/pypsaearthsec/with_h2_network_6h_ws/postnetworks/elec_s_10_ec_lc1.0_Co2L.50_6H_2030_0.071_DF_0export.nc
#with_h2_network_6h/prenetworks/elec_s_4_ec_lc1.0_Co2L1.0_6H_2030_0.071_DF_0export.nc
n = pypsa.Network(prefix + ald)
# Out:
# INFO:pypsa.io:Imported network elec_s_4_ec_lc1.0_Co2L.50_6H_2030_0.071_DF_20export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n. MAR.10.4_1 H2

# %%
n.buses[n.buses.carrier=="H2"]
# Out:
#                v_nom country          x          y control generator carrier  \
# Bus
# MAR.1.1_1 H2     1.0          -7.391333  33.463400   Slack                H2
# MAR.1.2_1 H2     1.0          -6.742127  32.788247   Slack                H2
# MAR.1.3_1 H2     1.0          -7.498526  33.093662   Slack                H2
# MAR.10.1_1 H2    1.0          -2.504553  34.684833   Slack                H2
# MAR.10.3_1 H2    1.0          -2.078180  34.238680   Slack                H2
# MAR.10.4_1 H2    1.0          -3.107325  35.112800   Slack                H2
# MAR.10.5_1 H2    1.0          -1.950887  34.667137   Slack                H2
# MAR.11.1_1 H2    1.0          -6.147667  33.781200   Slack                H2
# MAR.11.3_1 H2    1.0          -6.690040  33.987200   Slack                H2
# MAR.11.4_1 H2    1.0          -6.829450  33.879000   Slack                H2
# MAR.12.1_1 H2    1.0          -9.485353  30.422240   Slack                H2
# MAR.12.2_1 H2    1.0          -9.326400  30.151750   Slack                H2
# MAR.12.3_1 H2    1.0          -9.375633  30.394433   Slack                H2
# MAR.12.4_1 H2    1.0          -6.119700  31.265877   Slack                H2
# MAR.12.5_1 H2    1.0          -8.771067  30.479583   Slack                H2
# MAR.12.6_1 H2    1.0          -9.651620  29.629730   Slack                H2
# MAR.12.7_1 H2    1.0          -6.459100  30.685000   Slack                H2
# MAR.13.1_1 H2    1.0          -6.598150  32.050433   Slack                H2
# MAR.13.2_1 H2    1.0          -6.541992  32.552969   Slack                H2
# MAR.14.1_1 H2    1.0          -5.316100  35.216800   Slack                H2
# MAR.14.2_1 H2    1.0          -5.741817  35.708933   Slack                H2
# MAR.14.3_1 H2    1.0          -6.027400  35.044450   Slack                H2
# MAR.14.4_1 H2    1.0          -5.839729  35.693814   Slack                H2
# MAR.14.5_1 H2    1.0          -5.544778  35.677587   Slack                H2
# MAR.15.1_1 H2    1.0          -3.933950  35.084350   Slack                H2
# MAR.15.2_1 H2    1.0          -4.678367  34.114067   Slack                H2
# MAR.15.3_1 H2    1.0          -3.848787  34.279562   Slack                H2
# MAR.2.1_1 H2     1.0          -8.423032  33.098172   Slack                H2
# MAR.2.2_1 H2     1.0          -8.806900  32.074080   Slack                H2
# MAR.3.2_1 H2     1.0          -4.972780  34.009620   Slack                H2
# MAR.3.3_1 H2     1.0          -4.771750  33.921567   Slack                H2
# MAR.3.4_1 H2     1.0          -5.082386  34.024457   Slack                H2
# MAR.4.1_1 H2     1.0          -6.235860  34.626520   Slack                H2
# MAR.4.2_1 H2     1.0          -5.767767  34.554200   Slack                H2
# MAR.5.1_1 H2     1.0          -7.547417  33.529392   Slack                H2
# MAR.5.2_1 H2     1.0          -7.428767  33.671167   Slack                H2
# MAR.6.3_1 H2     1.0         -11.168600  28.479000   Slack                H2
# MAR.8.1_1 H2     1.0          -7.531033  31.603700   Slack                H2
# MAR.8.2_1 H2     1.0          -8.718433  31.486256   Slack                H2
# MAR.8.3_1 H2     1.0          -7.709415  32.089754   Slack                H2
# MAR.8.4_1 H2     1.0          -9.580600  31.546100   Slack                H2
# MAR.8.5_1 H2     1.0          -8.111080  31.707980   Slack                H2
# MAR.9.1_1 H2     1.0          -5.527300  33.672800   Slack                H2
# MAR.9.2_1 H2     1.0          -4.499500  31.771380   Slack                H2
# MAR.9.3_1 H2     1.0          -5.185800  33.495850   Slack                H2
# MAR.9.4_1 H2     1.0          -5.305600  32.896143   Slack                H2
# MAR.9.5_1 H2     1.0          -5.612346  33.940292   Slack                H2
# H2 export bus    1.0         -12.981168  37.567953   Slack                H2
#
#                  location type  unit  v_mag_pu_set  v_mag_pu_min  \
# Bus
# MAR.1.1_1 H2    MAR.1.1_1       None           1.0           0.0
# MAR.1.2_1 H2    MAR.1.2_1       None           1.0           0.0
# MAR.1.3_1 H2    MAR.1.3_1       None           1.0           0.0
# MAR.10.1_1 H2  MAR.10.1_1       None           1.0           0.0
# MAR.10.3_1 H2  MAR.10.3_1       None           1.0           0.0
# MAR.10.4_1 H2  MAR.10.4_1       None           1.0           0.0
# MAR.10.5_1 H2  MAR.10.5_1       None           1.0           0.0
# MAR.11.1_1 H2  MAR.11.1_1       None           1.0           0.0
# MAR.11.3_1 H2  MAR.11.3_1       None           1.0           0.0
# MAR.11.4_1 H2  MAR.11.4_1       None           1.0           0.0
# MAR.12.1_1 H2  MAR.12.1_1       None           1.0           0.0
# MAR.12.2_1 H2  MAR.12.2_1       None           1.0           0.0
# MAR.12.3_1 H2  MAR.12.3_1       None           1.0           0.0
# MAR.12.4_1 H2  MAR.12.4_1       None           1.0           0.0
# MAR.12.5_1 H2  MAR.12.5_1       None           1.0           0.0
# MAR.12.6_1 H2  MAR.12.6_1       None           1.0           0.0
# MAR.12.7_1 H2  MAR.12.7_1       None           1.0           0.0
# MAR.13.1_1 H2  MAR.13.1_1       None           1.0           0.0
# MAR.13.2_1 H2  MAR.13.2_1       None           1.0           0.0
# MAR.14.1_1 H2  MAR.14.1_1       None           1.0           0.0
# MAR.14.2_1 H2  MAR.14.2_1       None           1.0           0.0
# MAR.14.3_1 H2  MAR.14.3_1       None           1.0           0.0
# MAR.14.4_1 H2  MAR.14.4_1       None           1.0           0.0
# MAR.14.5_1 H2  MAR.14.5_1       None           1.0           0.0
# MAR.15.1_1 H2  MAR.15.1_1       None           1.0           0.0
# MAR.15.2_1 H2  MAR.15.2_1       None           1.0           0.0
# MAR.15.3_1 H2  MAR.15.3_1       None           1.0           0.0
# MAR.2.1_1 H2    MAR.2.1_1       None           1.0           0.0
# MAR.2.2_1 H2    MAR.2.2_1       None           1.0           0.0
# MAR.3.2_1 H2    MAR.3.2_1       None           1.0           0.0
# MAR.3.3_1 H2    MAR.3.3_1       None           1.0           0.0
# MAR.3.4_1 H2    MAR.3.4_1       None           1.0           0.0
# MAR.4.1_1 H2    MAR.4.1_1       None           1.0           0.0
# MAR.4.2_1 H2    MAR.4.2_1       None           1.0           0.0
# MAR.5.1_1 H2    MAR.5.1_1       None           1.0           0.0
# MAR.5.2_1 H2    MAR.5.2_1       None           1.0           0.0
# MAR.6.3_1 H2    MAR.6.3_1       None           1.0           0.0
# MAR.8.1_1 H2    MAR.8.1_1       None           1.0           0.0
# MAR.8.2_1 H2    MAR.8.2_1       None           1.0           0.0
# MAR.8.3_1 H2    MAR.8.3_1       None           1.0           0.0
# MAR.8.4_1 H2    MAR.8.4_1       None           1.0           0.0
# MAR.8.5_1 H2    MAR.8.5_1       None           1.0           0.0
# MAR.9.1_1 H2    MAR.9.1_1       None           1.0           0.0
# MAR.9.2_1 H2    MAR.9.2_1       None           1.0           0.0
# MAR.9.3_1 H2    MAR.9.3_1       None           1.0           0.0
# MAR.9.4_1 H2    MAR.9.4_1       None           1.0           0.0
# MAR.9.5_1 H2    MAR.9.5_1       None           1.0           0.0
# H2 export bus                   None           1.0           0.0
#
#                v_mag_pu_max sub_network
# Bus
# MAR.1.1_1 H2            inf
# MAR.1.2_1 H2            inf
# MAR.1.3_1 H2            inf
# MAR.10.1_1 H2           inf
# MAR.10.3_1 H2           inf
# MAR.10.4_1 H2           inf
# MAR.10.5_1 H2           inf
# MAR.11.1_1 H2           inf
# MAR.11.3_1 H2           inf
# MAR.11.4_1 H2           inf
# MAR.12.1_1 H2           inf
# MAR.12.2_1 H2           inf
# MAR.12.3_1 H2           inf
# MAR.12.4_1 H2           inf
# MAR.12.5_1 H2           inf
# MAR.12.6_1 H2           inf
# MAR.12.7_1 H2           inf
# MAR.13.1_1 H2           inf
# MAR.13.2_1 H2           inf
# MAR.14.1_1 H2           inf
# MAR.14.2_1 H2           inf
# MAR.14.3_1 H2           inf
# MAR.14.4_1 H2           inf
# MAR.14.5_1 H2           inf
# MAR.15.1_1 H2           inf
# MAR.15.2_1 H2           inf
# MAR.15.3_1 H2           inf
# MAR.2.1_1 H2            inf
# MAR.2.2_1 H2            inf
# MAR.3.2_1 H2            inf
# MAR.3.3_1 H2            inf
# MAR.3.4_1 H2            inf
# MAR.4.1_1 H2            inf
# MAR.4.2_1 H2            inf
# MAR.5.1_1 H2            inf
# MAR.5.2_1 H2            inf
# MAR.6.3_1 H2            inf
# MAR.8.1_1 H2            inf
# MAR.8.2_1 H2            inf
# MAR.8.3_1 H2            inf
# MAR.8.4_1 H2            inf
# MAR.8.5_1 H2            inf
# MAR.9.1_1 H2            inf
# MAR.9.2_1 H2            inf
# MAR.9.3_1 H2            inf
# MAR.9.4_1 H2            inf
# MAR.9.5_1 H2            inf
# H2 export bus           inf

# %%
n.links[n.links.carrier == "H2"]
# Out:
#                                bus0           bus1 carrier  efficiency  \
# Link
# MAR.10.4_1 H2 export  MAR.10.4_1 H2  H2 export bus      H2         1.0
# MAR.14.1_1 H2 export  MAR.14.1_1 H2  H2 export bus      H2         1.0
# MAR.14.3_1 H2 export  MAR.14.3_1 H2  H2 export bus      H2         1.0
# MAR.12.6_1 H2 export  MAR.12.6_1 H2  H2 export bus      H2         1.0
# MAR.2.1_1 H2 export    MAR.2.1_1 H2  H2 export bus      H2         1.0
#
#                       p_nom_extendable bus2 bus3 bus4  capital_cost  \
# Link
# MAR.10.4_1 H2 export              True                          0.0
# MAR.14.1_1 H2 export              True                          0.0
# MAR.14.3_1 H2 export              True                          0.0
# MAR.12.6_1 H2 export              True                          0.0
# MAR.2.1_1 H2 export               True                          0.0
#
#                       efficiency2  ...  charger_ratio  type  build_year  \
# Link                               ...
# MAR.10.4_1 H2 export          1.0  ...            NaN                 0
# MAR.14.1_1 H2 export          1.0  ...            NaN                 0
# MAR.14.3_1 H2 export          1.0  ...            NaN                 0
# MAR.12.6_1 H2 export          1.0  ...            NaN                 0
# MAR.2.1_1 H2 export           1.0  ...            NaN                 0
#
#                       p_nom_min  p_nom_max  p_set  p_max_pu  terrain_factor  \
# Link
# MAR.10.4_1 H2 export        0.0        inf    0.0       1.0             1.0
# MAR.14.1_1 H2 export        0.0        inf    0.0       1.0             1.0
# MAR.14.3_1 H2 export        0.0        inf    0.0       1.0             1.0
# MAR.12.6_1 H2 export        0.0        inf    0.0       1.0             1.0
# MAR.2.1_1 H2 export         0.0        inf    0.0       1.0             1.0
#
#                       ramp_limit_up  ramp_limit_down
# Link
# MAR.10.4_1 H2 export            NaN              NaN
# MAR.14.1_1 H2 export            NaN              NaN
# MAR.14.3_1 H2 export            NaN              NaN
# MAR.12.6_1 H2 export            NaN              NaN
# MAR.2.1_1 H2 export             NaN              NaN
#
# [5 rows x 29 columns]

# %%
n.global_constraints
# Out:
#                                                type carrier_attribute sense  \
# GlobalConstraint
# CO2Limit                             primary_energy     co2_emissions    <=
# lc_limit          transmission_expansion_cost_limit            AC, DC    <=
#
#                       constant  investment_period   mu
# GlobalConstraint
# CO2Limit          4.000000e+07                NaN  0.0
# lc_limit          4.817521e+08                NaN  0.0

# %%
#n.stores.loc["co2 atmosphere"]

# %%
(n.stores_t.p["co2 atmosphere"]*n.snapshot_weightings.generators[0]).sum()/1e6
# Out:
# 10.402205764837586

# %%
# Plot the energy in the store named "co2 atmosphere" over time
n.stores_t.e["co2 atmosphere"][-1]/1e6 #.plot()
# Out:
# -10.422526163577526

# %%
# Get the energy of all generators grouped by carrier
n.generators_t.p.groupby(n.generators.carrier,axis=1).sum().sum()/1e6*n.snapshot_weightings.generators[0] #in TWh

# %%
#n.generators.p_nom_opt.groupby(n.generators.carrier).sum()/1e3

# %%
# Get the energy of all loads grouped by carrier using the snapshot_weightings and loads_t.p_set
n.loads_t.p.groupby(n.loads.carrier,axis=1).sum().sum()/1e6*n.snapshot_weightings.generators[0] #in TWh

# %%
# Total capacity Fischer-Tropsch    
n.links[n.links.carrier.str.contains('Fischer-Tropsch')].p_nom_opt.sum() /1e3 # in GW

# %%
# Get the energy of Fischer tropsch
n.links_t.p0[n.links[n.links.carrier.str.contains('Fischer-Tropsch')].index].sum().sum()*n.snapshot_weightings.generators[0]/1e6 # in TWh

# %%
n.buses_t.p

# %%
n.buses_t.p[n.buses.carrier.str.contains('oil')]
